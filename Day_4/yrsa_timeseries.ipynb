# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib --list
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'gtk4', 'wx', 'qt4', 'qt5', 'qt6', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %%
# %matplotlib inline
#%matplotlib notebook

# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\au708090\OneDrive\Dokument\PhD\Fungi experiment\Tetracyclines\fungi_Python.csv', header=0, sep=";")

# %%
print(data)
# Out:
#     X-axis         A         B         C
# 0        0  1.000000  1.000000  1.000000
# 1        2  0.863084  0.863084  1.027236
# 2        4  1.151079  0.741929  0.807346
# 3        6  0.494264  1.020785  1.033955
# 4        8  0.526167  0.405921  0.356998
# 5       25  0.453115  0.528937  0.565031
# 6       31  0.000000  0.417144  0.051162
# 7       52  0.000000  0.000000  0.000000
# 8       74  0.000000  0.000000  0.000000
# 9       97  0.000000  0.000000  0.000000
# 10     175  0.000000  0.000000  0.000000
# 11     221  0.000000  0.000000  0.000000
# 12     268  0.000000  0.000000  0.000000
# 13     336  0.000000  0.000000  0.000000

# %%
data["X-axis"]
# Out:
# 0       0
# 1       2
# 2       4
# 3       6
# 4       8
# 5      25
# 6      31
# 7      52
# 8      74
# 9      97
# 10    175
# 11    221
# 12    268
# 13    336
# Name: X-axis, dtype: int64

# %%
sns.lineplot(x="X-axis", y="A", data=data)
sns.lineplot(x="X-axis", y="B", data=data)
sns.lineplot(x="X-axis", y="C", data=data)
# Out:
# <AxesSubplot:xlabel='X-axis', ylabel='A'>

# %%
fig, ax= plt.subplots()
ax.errorbar(Time, A; B; C)
plt.show()

# %%
import pandas as pd
BAC_data=pd.read_excel(r'C:\Users\au708090\OneDrive\Dokument\PhD\Fungi experiment\Tetracyclines\fungi_Python.xlsx')

# %%
sns.lineplot(data=BAC_kinetics, x="Time", y="value")
sns.lineplot(data=BAC_kinetics, x="Time", y="value", ci='sd', err_style='bars', color='blue')
plt.xlim(0,100)
plt.xlabel('Time [hours]')
plt.ylabel('C/C0')
plt.title('BAC-12 degradation in fungi reactors')
# Out:
# Text(0.5, 1.0, 'BAC-12 degradation in fungi reactors')

# %%
print(BAC_kinetics)
# Out:
#     Time variable     value
# 0      0        A  1.000000
# 1      2        A  0.863084
# 2      4        A  1.151079
# 3      6        A  0.494264
# 4      8        A  0.526167
# 5     25        A  0.453115
# 6     31        A  0.000000
# 7     52        A  0.000000
# 8     74        A  0.000000
# 9     97        A  0.000000
# 10   175        A  0.000000
# 11   221        A  0.000000
# 12   268        A  0.000000
# 13   336        A  0.000000
# 14     0        B  1.000000
# 15     2        B  0.863084
# 16     4        B  0.741929
# 17     6        B  1.020785
# 18     8        B  0.405921
# 19    25        B  0.528937
# 20    31        B  0.417144
# 21    52        B  0.000000
# 22    74        B  0.000000
# 23    97        B  0.000000
# 24   175        B  0.000000
# 25   221        B  0.000000
# 26   268        B  0.000000
# 27   336        B  0.000000
# 28     0        C  1.000000
# 29     2        C  1.027236
# 30     4        C  0.807346
# 31     6        C  1.033955
# ...
